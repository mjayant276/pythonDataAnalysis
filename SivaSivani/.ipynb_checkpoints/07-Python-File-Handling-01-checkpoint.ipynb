# %% [markdown]
# #### In this section we will try to see how files are handled in python.

# %%
## With open is like opening the connection to the file
with open('data.txt', 'w') as f:
    print("Welcome to Python Programming !", file=f)

# %%
f
# Out:
# <_io.TextIOWrapper name='data.txt' mode='w' encoding='cp1252'>

# %% [markdown]
# The first argument we passed to `open` was the path we wanted to write.
# Our path was more like a filename than a path, so the file ended up in
# the current working directory.
#
# The second argument was `w`. It's short for write, and that just means
# that we'll create a new file. There's some other modes we can use also:
#
# | Mode  | Short for | Meaning                                                               |
# |-------|-----------|-----------------------------------------------------------------------|
# | `r`   | read      | Read from an existing file.                                           |
# | `w`   | write     | Write to a file. **If the file exists, its old content is removed.**  |
# | `a`   | append    | Write to the end of a file, and keep the old content.                 |
# | `r+`  | read &    | This is for both reading and writing.                                 |
# |       |   write   |                                                                       |
# | `w+`  | read      | This is for both reading and writing.                                 |
# |       | & write   |                                                                       |
# |  `a+` | read      |  This is for both reading and appending                               |
# |       | & append  |                                                                       |
# As we can see,
# the file was indeed closed.

# %%
f.closed
# Out:
# True

# %% [markdown]
# ## Reading from files
#
# After opening a file with the `r` mode we can for loop over it, just
# like it was a list. So let's go ahead and read everything in the file
# we created to a list of lines.

# %%
lines = []
with open('data.txt', 'r') as f:
    for line in f:
        lines.append(line)

# %%
lines
# Out:
# ['Python programming - Insofe lab insofe!\n']

# %% [markdown]
# ```
#
# Trying to open a non-existent file with `w` or `a` creates the file for
# us, but doing that with `r` gives us an error instead. We'll learn more
# about errors
#
# ```

# %%
with open('file-doesnt-exist.txt', 'r') as f:
    print("It's working!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-b549af70a27c> in <module>
# ----> 1 with open('file-doesnt-exist.txt', 'r') as f:
#       2     print("It's working!")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file-doesnt-exist.txt'

# %%
with open('data.txt','w') as f:
    print('Chota Bheem, who plays the central role in the story is an adventurous boy.',file=f)
    print('Almost all the people from Dholakpur look up to Bheem for the solutions to their problems',file=f)
    print('When she and Bheem are fighting bad guys, he asks her to give her a laddu',file=f)

# %%
lines = []
with open('data.txt','r') as f:
    for line in f:
        lines.append(line)

# %%
lines
# Out:
# ['Chota Bheem, who plays the central role in the story is an adventurous boy.\n',
#  'Almost all the people from Dholakpur look up to Bheem for the solutions to their problems\n',
#  'When she and Bheem are fighting bad guys, he asks her to give her a laddu\n']

# %% [markdown]
# We need to remove the `\n` characters that are append at the end of the sentence in the above list.
# [The rstrip string
# method](https://docs.python.org/3/library/stdtypes.html#str.rstrip) is helpful to remove the `\n` characters

# %%
stripped = []
for line in lines:
    stripped.append(line.rstrip('\n'))
stripped
# Out:
# ['Chota Bheem, who plays the central role in the story is an adventurous boy.',
#  'Almost all the people from Dholakpur look up to Bheem for the solutions to their problems',
#  'When she and Bheem are fighting bad guys, he asks her to give her a laddu']

# %% [markdown]
# It's also possible to read lines one by one. Files have [a readline
# method](https://docs.python.org/3/library/io.html#io.TextIOBase.readline)
# that reads the next line, and returns `''` if we're at the end of the file.

# %%
with open('data.txt', 'r') as f:
    first_line = f.readline()
    second_line = f.readline()

# %%
first_line
# Out:
# 'Chota Bheem, who plays the central role in the story is an adventurous boy.\n'

# %%
second_line
# Out:
# 'Almost all the people from Dholakpur look up to Bheem for the solutions to their problems\n'

# %% [markdown]
# The files can only be read once - using the read line if try to read it again it don't work

# %%
## Create two list to open the file and then iterate over the contents of the list to append data content.
readList_1 = []
readList_2 = []
with open('data.txt', 'r') as f:
    for line in f:
        readList_1.append(line)
    for line in f:
        readList_2.append(line)

# %%
readList_1
# Out:
# ['Chota Bheem, who plays the central role in the story is an adventurous boy.\n',
#  'Almost all the people from Dholakpur look up to Bheem for the solutions to their problems\n',
#  'When she and Bheem are fighting bad guys, he asks her to give her a laddu\n']

# %%
readList_2
# Out:
# []

# %% [markdown]
# ```
#
# File objects remember their position. When we tried to read the
# file again it was already at the end, and there was nothing left
# to read. But if we open the file again, we get a new file object that
# is in the beginning and everything works.
#
# ```

# %%
### Two separate list are created to append the contents of the file separately
readList_1 = []
readList_2 = []

# %%
with open('data.txt', 'r') as f:
    for line in f:
        readList_1.append(line)

# %%
readList_1
# Out:
# ['Chota Bheem, who plays the central role in the story is an adventurous boy.\n',
#  'Almost all the people from Dholakpur look up to Bheem for the solutions to their problems\n',
#  'When she and Bheem are fighting bad guys, he asks her to give her a laddu\n']

# %%
with open('data.txt', 'r') as f:
    for line in f:
        readList_2.append(line)

# %%
readList_2
# Out:
# ['Chota Bheem, who plays the central role in the story is an adventurous boy.\n',
#  'Almost all the people from Dholakpur look up to Bheem for the solutions to their problems\n',
#  'When she and Bheem are fighting bad guys, he asks her to give her a laddu\n']

# %% [markdown]
# If we need all of the content as a string, we can use [the read
# method](https://docs.python.org/3/library/io.html#io.TextIOBase.read).

# %%
with open('data.txt', 'r') as f:
    data_complete = f.read()

# %%
data_complete
# Out:
# 'Chota Bheem, who plays the central role in the story is an adventurous boy.\nAlmost all the people from Dholakpur look up to Bheem for the solutions to their problems\nWhen she and Bheem are fighting bad guys, he asks her to give her a laddu\n'

# %% [markdown]
# The tell() method tells you the current position within the file; in other words, the next read or write will occur at that many bytes from the beginning of the file.
#
# The seek(offset[, from]) method changes the current file position. The offset argument indicates the number of bytes to be moved. The from argument specifies the reference position from where the bytes are to be moved.
#
# If from is set to 0, the beginning of the file is used as the reference position. If it is set to 1, the current position is used as the reference position. If it is set to 2 then the end of the file would be taken as the reference position.

# %%
fileptr = open("data.txt","r")    
    
#initially the filepointer is at 0     
print("The filepointer is at byte :",fileptr.tell())    
    
#changing the file pointer location to 10.    
fileptr.seek(10);    
    
#tell() returns the location of the fileptr.     
print("After reading, the filepointer is at:",fileptr.tell())
# Out:
# The filepointer is at byte : 0
# After reading, the filepointer is at: 10

# %%
# Open a file
data = open("data.txt", "r+")
file_data = data.read(27) 
print("current position after reading 27 byte :",data.tell())
data.seek(0) #here current position set to 0 (starting of file)
full_data = data.read() #read all byte
print(file_data)
print(full_data)
print("position after reading file : ",data.tell())
data.close()
# Out:
# current position after reading 27 byte : 27
# Chota Bheem, who plays the
# Chota Bheem, who plays the central role in the story is an adventurous boy.
# Almost all the people from Dholakpur look up to Bheem for the solutions to their problems
# When she and Bheem are fighting bad guys, he asks her to give her a laddu
#
# position after reading file :  240

# %%
while True:
    answer = input("Have you been here before? (y/n) ")
    if answer == 'Y' or answer == 'y':
        been_here_before = True
        break
    elif answer == 'N' or answer == 'n':
        been_here_before = False
        break
    else:
        print("Enter 'y' or 'n'.")

if been_here_before:
    # Read username and password from a file.
    with open('userinfo.txt', 'r') as f:
        username = f.readline().rstrip('\n')
        password = f.readline().rstrip('\n')

    if input("Username: ") != username:
        print("Wrong username!")
    elif input("Password: ") != password:
        print("Wrong password!")
    else:
        print("Correct username and password, welcome!")

else:
    # Write username and password to a file.
    username = input("Username: ")
    password = input("Password: ")
    with open('userinfo.txt', 'w') as f:
        print(username, file=f)
        print(password, file=f)

    print("Done! Now run this program again and select 'y'.")
# Out:
# Have you been here before? (y/n)  y
# Username:  1024
# Password:  setword_00099
# Correct username and password, welcome!

# %% [markdown]
# #### Reading excel files in the python

# %%
import sys
import os
import xlrd
import openpyxl
import unicodecsv

# %%
# Open the workbook and define the worksheet
book = xlrd.open_workbook("train_data.xls")
sheet = book.sheet_by_name("train")
# Create a For loop to iterate through each row in the XLS file, starting at row 2 to skip the headers
for r in range(1, sheet.nrows):
        user_ID = sheet.cell(r,0).value
        product_ID  = sheet.cell(r,1).value
        gender      = sheet.cell(r,2).value
        age    = sheet.cell(r,3).value
        occupation = sheet.cell(r,4).value
        city_category= sheet.cell(r,5).value
        stay_in_curr_city= sheet.cell(r,6).value
        marital_status= sheet.cell(r,7).value 
        product_cat_1 = sheet.cell(r,8).value
        product_cat_2 = sheet.cell(r,9).value
        product_cat_3= sheet.cell(r,10).value
        purchase= sheet.cell(r,11).value
        print("User Id: {} Product Id: {} Gender: {} Age: {} Occupation: {} \n".format(user_ID, product_ID,gender,age,occupation))
# Out:
# User Id: 1000001.0 Product Id: P00069042 Gender: F Age: 0-17 Occupation: 10.0
#
# User Id: 1000001.0 Product Id: P00248942 Gender: F Age: 0-17 Occupation: 10.0
#
# User Id: 1000001.0 Product Id: P00087842 Gender: F Age: 0-17 Occupation: 10.0
#
# User Id: 1000001.0 Product Id: P00085442 Gender: F Age: 0-17 Occupation: 10.0
#
# User Id: 1000002.0 Product Id: P00285442 Gender: M Age: 55+ Occupation: 16.0
#
# User Id: 1000003.0 Product Id: P00193542 Gender: M Age: 26-35 Occupation: 15.0
#
# User Id: 1000004.0 Product Id: P00184942 Gender: M Age: 46-50 Occupation: 7.0
#
# User Id: 1000004.0 Product Id: P00346142 Gender: M Age: 46-50 Occupation: 7.0
#
# User Id: 1000004.0 Product Id: P0097242 Gender: M Age: 46-50 Occupation: 7.0
#
# User Id: 1000005.0 Product Id: P00274942 Gender: M Age: 26-35 Occupation: 20.0
#
# User Id: 1000005.0 Product Id: P00251242 Gender: M Age: 26-35 Occupation: 20.0
#
# User Id: 1000005.0 Product Id: P00014542 Gender: M Age: 26-35 Occupation: 20.0
#
# User Id: 1000005.0 Product Id: P00031342 Gender: M Age: 26-35 Occupation: 20.0
#
# User Id: 1000005.0 Product Id: P00145042 Gender: M Age: 26-35 Occupation: 20.0
#
# User Id: 1000006.0 Product Id: P00231342 Gender: F Age: 51-55 Occupation: 9.0
#
# User Id: 1000006.0 Product Id: P00190242 Gender: F Age: 51-55 Occupation: 9.0
#
# User Id: 1000006.0 Product Id: P0096642 Gender: F Age: 51-55 Occupation: 9.0
#
# User Id: 1000006.0 Product Id: P00058442 Gender: F Age: 51-55 Occupation: 9.0
#
# User Id: 1000007.0 Product Id: P00036842 Gender: M Age: 36-45 Occupation: 1.0
#
# User Id: 1000008.0 Product Id: P00249542 Gender: M Age: 26-35 Occupation: 12.0
#
# User Id: 1000008.0 Product Id: P00220442 Gender: M Age: 26-35 Occupation: 12.0
#
# User Id: 1000008.0 Product Id: P00156442 Gender: M Age: 26-35 Occupation: 12.0
#
# User Id: 1000008.0 Product Id: P00213742 Gender: M Age: 26-35 Occupation: 12.0
#
# User Id: 1000008.0 Product Id: P00214442 Gender: M Age: 26-35 Occupation: 12.0
#
# User Id: 1000008.0 Product Id: P00303442 Gender: M Age: 26-35 Occupation: 12.0
#
# User Id: 1000009.0 Product Id: P00135742 Gender: M Age: 26-35 Occupation: 17.0
#
# User Id: 1000009.0 Product Id: P00039942 Gender: M Age: 26-35 Occupation: 17.0
#
# User Id: 1000009.0 Product Id: P00161442 Gender: M Age: 26-35 Occupation: 17.0
#
# User Id: 1000009.0 Product Id: P00078742 Gender: M Age: 26-35 Occupation: 17.0
#
# User Id: 1000010.0 Product Id: P00085942 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00118742 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00297942 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00266842 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00058342 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00032442 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00105942 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00182642 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00186942 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00155442 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00221342 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00087242 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00111142 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00259342 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P0094542 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00148642 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00312142 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000010.0 Product Id: P00113242 Gender: F Age: 36-45 Occupation: 1.0
#
# User Id: 1000011.0 Product Id: P00192642 Gender: F Age: 26-35 Occupation: 1.0
#
# User Id: 1000011.0 Product Id: P00110842 Gender: F Age: 26-35 Occupation: 1.0

# %% [markdown]
# ### Reading an xml file using the python library

# %%
from xml.dom.minidom import parse
import xml.dom.minidom

# %%
# Open XML document using minidom parser
DOMTree = xml.dom.minidom.parse("reed.xml")
collection = DOMTree.documentElement
if collection.hasAttribute("courses"):
   print ("Root element : %s" % collection.getAttribute("courses"))

# Get all the course from the collection/root element course
courses = collection.getElementsByTagName("COURSE")

# Print detail of each course.
for course in courses:
    print ("*****Course*****")
    reg_num = course.getElementsByTagName('REG_NUM')[0]
    print ("Type: %s" % reg_num.childNodes[0].data)
    subj = course.getElementsByTagName('SUBJ')[0]
    print ("Format: %s" % subj.childNodes[0].data)
    crse = course.getElementsByTagName('CRSE')[0]
    print ("Rating: %s" % crse.childNodes[0].data)
    sect = course.getElementsByTagName('SECT')[0]
    print ("Description: %s" % sect.childNodes[0].data)
    title = course.getElementsByTagName('TITLE')[0]
    print ("Description: %s" % title.childNodes[0].data)
# Out:
# Root element : ANTH
# *****Course*****
# Type: 10577
# Format: ANTH
# Rating: 211
# Description: F01
# Description: Introduction to Anthropology
# *****Course*****
# Type: 20573
# Format: ANTH
# Rating: 344
# Description: S01
# Description: Sex and Gender
# *****Course*****
# Type: 10624
# Format: BIOL
# Rating: 431
# Description: F01
# Description: Field Biology of Amphibians
# *****Course*****
# Type: 10626
# Format: BIOL
# Rating: 431
# Description: F03
# Description: Bacterial Pathogenesis
# *****Course*****
# Type: 20626
# Format: BIOL
# Rating: 431
# Description: S04
# Description: Seminar in Biology
# *****Course*****
# Type: 10543
# Format: CHEM
# Rating: 101
# Description: F
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10544
# Format: CHEM
# Rating: 101
# Description: F01
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10545
# Format: CHEM
# Rating: 101
# Description: F02
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10546
# Format: CHEM
# Rating: 101
# Description: F03
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10789
# Format: CHEM
# Rating: 101
# Description: F08
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10547
# Format: CHEM
# Rating: 101
# Description: F04
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10548
# Format: CHEM
# Rating: 101
# Description: F05
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 20575
# Format: ANTH
# Rating: 344
# Description: S02
# Description: Sex and Gender
# *****Course*****
# Type: 10549
# Format: CHEM
# Rating: 101
# Description: F06
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10550
# Format: CHEM
# Rating: 101
# Description: F07
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10551
# Format: CHEM
# Rating: 101
# Description: FL1
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10555
# Format: CHEM
# Rating: 101
# Description: FL5
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10552
# Format: CHEM
# Rating: 101
# Description: FL2
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10553
# Format: CHEM
# Rating: 101
# Description: FL3
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10557
# Format: CHEM
# Rating: 101
# Description: FL7
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10556
# Format: CHEM
# Rating: 101
# Description: FL6
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10554
# Format: CHEM
# Rating: 101
# Description: FL4
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 10558
# Format: CHEM
# Rating: 101
# Description: FL8
# Description: MolecularStructure and Properties
# *****Course*****
# Type: 20483
# Format: ANTH
# Rating: 348
# Description: S
# Description: Languages the Americas:Mayan
# *****Course*****
# Type: 20537
# Format: CHEM
# Rating: 102
# Description: S
# Description: Chemical Reactivity
# *****Course*****
# Type: 20538
# Format: CHEM
# Rating: 102
# Description: S01
# Description: Chemical Reactivity
# *****Course*****
# Type: 20539
# Format: CHEM
# Rating: 102
# Description: S02
# Description: Chemical Reactivity
# *****Course*****
# Type: 20540
# Format: CHEM
# Rating: 102
# Description: S03
# Description: Chemical Reactivity
# *****Course*****
# Type: 20541
# Format: CHEM
# Rating: 102
# Description: S04
# Description: Chemical Reactivity
# *****Course*****
# Type: 20542
# Format: CHEM
# Rating: 102
# Description: S05
# Description: Chemical Reactivity
# *****Course*****
# Type: 20543
# Format: CHEM
# Rating: 102
# Description: SL1
# Description: Chemical Reactivity
# *****Course*****
# Type: 20544
# Format: CHEM
# Rating: 102
# Description: SL2
# Description: Chemical Reactivity
# *****Course*****
# Type: 20545
# Format: CHEM
# Rating: 102
# Description: SL3
# Description: Chemical Reactivity
# *****Course*****
# Type: 20546
# Format: CHEM
# Rating: 102
# Description: SL4
# Description: Chemical Reactivity
# *****Course*****
# Type: 20667
# Format: ANTH
# Rating: 352
# Description: S
# Description: Anthropology of Europe
# *****Course*****
# Type: 20547
# Format: CHEM
# Rating: 102
# Description: SL5
# Description: Chemical Reactivity
# *****Course*****
# Type: 10559
# Format: CHEM
# Rating: 201
# Description: F
# Description: Organic Chemistry I
# *****Course*****
# Type: 10560
# Format: CHEM
# Rating: 201
# Description: F01
# Description: Organic Chemistry I
# *****Course*****
# Type: 10561
# Format: CHEM
# Rating: 201
# Description: F02
# Description: Organic Chemistry I
# *****Course*****
# Type: 10562
# Format: CHEM
# Rating: 201
# Description: F03
# Description: Organic Chemistry I
# *****Course*****
# Type: 10563
# Format: CHEM
# Rating: 201
# Description: F04
# Description: Organic Chemistry I
# *****Course*****
# Type: 10565
# Format: CHEM
# Rating: 201
# Description: FL1
# Description: Organic Chemistry I
# *****Course*****
# Type: 10566
# Format: CHEM
# Rating: 201
# Description: FL2
# Description: Organic Chemistry I
# *****Course*****
# Type: 10567
# Format: CHEM
# Rating: 201
# Description: FL3
# Description: Organic Chemistry I
# *****Course*****
# Type: 20548
# Format: CHEM
# Rating: 202
# Description: S
# Description: Organic Chemistry II
# *****Course*****
# Type: 20571
# Format: ANTH
# Rating: 357
# Description: S
# Description: Prob in IndonesianEthnography
# *****Course*****
# Type: 20549
# Format: CHEM
# Rating: 202
# Description: S01
# Description: Organic Chemistry II
# *****Course*****
# Type: 20550
# Format: CHEM
# Rating: 202
# Description: S02
# Description: Organic Chemistry II
# *****Course*****
# Type: 20551
# Format: CHEM
# Rating: 202
# Description: S03
# Description: Organic Chemistry II
# *****Course*****
# Type: 20552
# Format: CHEM
# Rating: 202
# Description: S04
# Description: Organic Chemistry II
# *****Course*****
# Type: 20554
# Format: CHEM
# Rating: 202
# Description: SL1
# Description: Organic Chemistry II
# *****Course*****
# Type: 20555
# Format: CHEM
# Rating: 202
# Description: SL2
# Description: Organic Chemistry II
# *****Course*****
# Type: 20556
# Format: CHEM
# Rating: 202
# Description: SL3
# Description: Organic Chemistry II
# *****Course*****
# Type: 20557
# Format: CHEM
# Rating: 212
# Description: S
# Description: Intro Inorganic Chemistry
# *****Course*****
# Type: 20559
# Format: CHEM
# Rating: 212
# Description: SL1
# Description: Intro Inorganic Chemistry
# *****Course*****
# Type: 20560
# Format: CHEM
# Rating: 212
# Description: SL2
# Description: Intro Inorganic Chemistry
# *****Course*****
# Type: 10605
# Format: ANTH
# Rating: 362
# Description: F
# Description: Gender and Ethnicity China, Tibet
# *****Course*****
# Type: 10582
# Format: CHEM
# Rating: 225
# Description: F
# Description: Environmental Chemistry
# *****Course*****
# Type: 10568
# Format: CHEM
# Rating: 271
# Description: F
# Description: Analytical Chemistry
# *****Course*****
# Type: 10569
# Format: CHEM
# Rating: 271
# Description: FL1
# Description: Analytical Chemistry
# *****Course*****
# Type: 10570
# Format: CHEM
# Rating: 271
# Description: FL2
# Description: Analytical Chemistry
# *****Course*****
# Type: 20561
# Format: CHEM
# Rating: 316
# Description: S
# Description: Physical Chemistry Laboratory
# *****Course*****
# Type: 20563
# Format: CHEM
# Rating: 324
# Description: S
# Description: Computational Organic Chem
# *****Course*****
# Type: 20564
# Format: CHEM
# Rating: 332
# Description: S
# Description: Statistical Thermodynamics
# *****Course*****
# Type: 10571
# Format: CHEM
# Rating: 333
# Description: F
# Description: Quantum Mechanics  and  MolStruct
# *****Course*****
# Type: 20565
# Format: CHEM
# Rating: 334
# Description: S
# Description: Advanced Inorganic Chemistry
# *****Course*****
# Type: 10572
# Format: CHEM
# Rating: 343
# Description: F
# Description: Adv Synth Organic Chemistry
# *****Course*****
# Type: 20570
# Format: ANTH
# Rating: 368
# Description: S
# Description: Myth
# *****Course*****
# Type: 10574
# Format: CHEM
# Rating: 391
# Description: F
# Description: Structural Biochemistry
# *****Course*****
# Type: 10576
# Format: CHEM
# Rating: 391
# Description: F02
# Description: Structural Biochemistry
# *****Course*****
# Type: 10575
# Format: CHEM
# Rating: 391
# Description: F01
# Description: Structural Biochemistry
# *****Course*****
# Type: 20566
# Format: CHEM
# Rating: 392
# Description: S
# Description: Metabolic Biochemistry
# *****Course*****
# Type: 20567
# Format: CHEM
# Rating: 394
# Description: S
# Description: Biochemical Methods
# *****Course*****
# Type: 20568
# Format: CHEM
# Rating: 394
# Description: SL1
# Description: Biochemical Methods
# *****Course*****
# Type: 20569
# Format: CHEM
# Rating: 394
# Description: SL2
# Description: Biochemical Methods
# *****Course*****
# Type: 10377
# Format: CHIN
# Rating: 110
# Description: Y
# Description: First Year Chinese
# *****Course*****
# Type: 10118
# Format: CHIN
# Rating: 210
# Description: Y
# Description: Second Year Chinese
# *****Course*****
# Type: 20598
# Format: CHIN
# Rating: 311
# Description: S
# Description: Third Year Chinese
# *****Course*****
# Type: 20572
# Format: ANTH
# Rating: 369
# Description: S
# Description: Media  and  Culture Post-MaoChina
# *****Course*****
# Type: 10629
# Format: CHIN
# Rating: 316
# Description: F
# Description: Classical Chinese
# *****Course*****
# Type: 10628
# Format: CHIN
# Rating: 321
# Description: F
# Description: 20 Cent Chin Fiction, 1919-49
# *****Course*****
# Type: 10630
# Format: CHIN
# Rating: 326
# Description: F
# Description: Chinese Narrative Tradition
# *****Course*****
# Type: 20596
# Format: CHIN
# Rating: 334
# Description: S
# Description: Yijing: Text and Tradition
# *****Course*****
# Type: 20601
# Format: CHIN
# Rating: 341
# Description: S
# Description: 20th Century Chinese Poetry
# *****Course*****
# Type: 20486
# Format: CLAS
# Rating: 363
# Description: S
# Description: Greek Tragedy
# *****Course*****
# Type: 10489
# Format: CLAS
# Rating: 373
# Description: F
# Description: Ancient History: Rome
# *****Course*****
# Type: 20488
# Format: CLAS
# Rating: 374
# Description: S
# Description: Specl Topics in Roman History
# *****Course*****
# Type: 20503
# Format: CRWR
# Rating: 201
# Description: S
# Description: Intro to Creative Writing
# *****Course*****
# Type: 10515
# Format: CRWR
# Rating: 211
# Description: F
# Description: Intro Poetry Writing
# *****Course*****
# Type: 20659
# Format: ANTH
# Rating: 372
# Description: S
# Description: Indians  and  Northrn NativeAmers
# *****Course*****
# Type: 20504
# Format: CRWR
# Rating: 211
# Description: S
# Description: Intro Poetry Writing
# *****Course*****
# Type: 10516
# Format: CRWR
# Rating: 221
# Description: F
# Description: Intro to Fiction Writing
# *****Course*****
# Type: 20642
# Format: CRWR
# Rating: 241
# Description: S
# Description: Intermediate Poetry: StudioII
# *****Course*****
# Type: 10517
# Format: CRWR
# Rating: 250
# Description: F
# Description: Intro to ScreenwritingWrkshop
# *****Course*****
# Type: 10518
# Format: CRWR
# Rating: 331
# Description: F
# Description: Adv Poet Writng: SequentVoice
# *****Course*****
# Type: 20506
# Format: CRWR
# Rating: 331
# Description: S
# Description: Adv Poet Writing:NaturalVoice
# *****Course*****
# Type: 10519
# Format: CRWR
# Rating: 332
# Description: F
# Description: Advanced Fiction Writing
# *****Course*****
# Type: 20507
# Format: CRWR
# Rating: 332
# Description: S
# Description: Advanced Fiction Writing
# *****Course*****
# Type: 10119
# Format: DANC
# Rating: 110
# Description: Y
# Description: Basic Technique
# *****Course*****
# Type: 10121
# Format: DANC
# Rating: 210
# Description: Y
# Description: Technique, Design  and Compostion
# *****Course*****
# Type: 20672
# Format: ANTH
# Rating: 374
# Description: S
# Description: Urban Anthropology
# *****Course*****
# Type: 20627
# Format: DANC
# Rating: 252
# Description: S
# Description: Improvisation
# *****Course*****
# Type: 10639
# Format: DANC
# Rating: 311
# Description: F
# Description: Adv Techniques  and  CompositionI
# *****Course*****
# Type: 20655
# Format: DANC
# Rating: 312
# Description: S
# Description: Adv Technique  and  CompositionII
# *****Course*****
# Type: 10631
# Format: DANC
# Rating: 330
# Description: F
# Description: Dance Theory and Criticism
# *****Course*****
# Type: 10324
# Format: ECON
# Rating: 201
# Description: F01
# Description: Intro to Economic Analysis
# *****Course*****
# Type: 10325
# Format: ECON
# Rating: 201
# Description: F02
# Description: Intro to Economic Analysis
# *****Course*****
# Type: 10326
# Format: ECON
# Rating: 201
# Description: FL1
# Description: Intro to Economic Analysis
# *****Course*****
# Type: 10327
# Format: ECON
# Rating: 201
# Description: FL2
# Description: Intro to Economic Analysis
# *****Course*****
# Type: 20319
# Format: ECON
# Rating: 201
# Description: S01
# Description: Intro to Economic Analysis
# *****Course*****
# Type: 20320
# Format: ECON
# Rating: 201
# Description: S02
# Description: Intro to Economic Analysis
# *****Course*****
# Type: 10578
# Format: ANTH
# Rating: 211
# Description: F02
# Description: Introduction to Anthropology
# *****Course*****
# Type: 10583
# Format: ANTH
# Rating: 378
# Description: F
# Description: Nature, Cult  and Envirnmentalism
# *****Course*****
# Type: 20321
# Format: ECON
# Rating: 201
# Description: SL1
# Description: Intro to Economic Analysis
# *****Course*****
# Type: 20322
# Format: ECON
# Rating: 201
# Description: SL2
# Description: Intro to Economic Analysis
# *****Course*****
# Type: 10584
# Format: ECON
# Rating: 311
# Description: F
# Description: Survey of Econometric Methods
# *****Course*****
# Type: 20574
# Format: ECON
# Rating: 312
# Description: S
# Description: Theory and  Practice Econometrics
# *****Course*****
# Type: 10585
# Format: ECON
# Rating: 313
# Description: F
# Description: Microeconomic Theory
# *****Course*****
# Type: 20576
# Format: ECON
# Rating: 314
# Description: S
# Description: Macroeconomic Theory
# *****Course*****
# Type: 20580
# Format: ECON
# Rating: 331
# Description: S
# Description: History of Economic Thought
# *****Course*****
# Type: 10587
# Format: ECON
# Rating: 341
# Description: F
# Description: Monetary and Fiscal Policy
# *****Course*****
# Type: 10589
# Format: ECON
# Rating: 342
# Description: F
# Description: International Macroeconomics
# *****Course*****
# Type: 20585
# Format: ECON
# Rating: 348
# Description: S
# Description: Economics of the PublicSECTor
# *****Course*****
# Type: 10586
# Format: ANTH
# Rating: 392
# Description: F01
# Description: Structuralism and Semiotics
# *****Course*****
# Type: 10590
# Format: ECON
# Rating: 351
# Description: F
# Description: Environment  and  Nat Resrce Econ
# *****Course*****
# Type: 10591
# Format: ECON
# Rating: 382
# Description: F
# Description: Economics of Development
# *****Course*****
# Type: 20582
# Format: ECON
# Rating: 383
# Description: S
# Description: International Trade
# *****Course*****
# Type: 10592
# Format: ECON
# Rating: 401
# Description: F
# Description: Seminar: Unemployment
# *****Course*****
# Type: 20602
# Format: ECON
# Rating: 413
# Description: S
# Description: Economics  and  Game Theory
# *****Course*****
# Type: 20592
# Format: ECON
# Rating: 442
# Description: S
# Description: Econ Envirn, Intl Trade,Devel
# *****Course*****
# Type: 10597
# Format: ECON
# Rating: 454
# Description: F
# Description: Economic Growth
# *****Course*****
# Type: 10503
# Format: ENG
# Rating: 201
# Description: F01
# Description: Intro Narr:Native AmericanLit
# *****Course*****
# Type: 10774
# Format: ENG
# Rating: 201
# Description: F02
# Description: Intro Narr: Telling Lives
# *****Course*****
# Type: 20508
# Format: ENG
# Rating: 201
# Description: S
# Description: Intro Narrative: The Essay
# *****Course*****
# Type: 10593
# Format: ANTH
# Rating: 392
# Description: F02
# Description: Structuralism and Semiotics
# *****Course*****
# Type: 10504
# Format: ENG
# Rating: 205
# Description: F01
# Description: Intro Fict:Colonl and LaterNovels
# *****Course*****
# Type: 10505
# Format: ENG
# Rating: 205
# Description: F02
# Description: Intro Fict:Portraits ofLadies
# *****Course*****
# Type: 20509
# Format: ENG
# Rating: 205
# Description: S
# Description: Intro Fict: The Short Story
# *****Course*****
# Type: 10506
# Format: ENG
# Rating: 211
# Description: F01
# Description: Intro to Poetry and Poetics
# *****Course*****
# Type: 10507
# Format: ENG
# Rating: 211
# Description: F02
# Description: Intro to Poetry and Poetics
# *****Course*****
# Type: 20510
# Format: ENG
# Rating: 211
# Description: S
# Description: Intro to Poetry and Poetics
# *****Course*****
# Type: 10758
# Format: ENG
# Rating: 242
# Description: F
# Description: Intro to Drama: The 1990s
# *****Course*****
# Type: 20511
# Format: ENG
# Rating: 242
# Description: S01
# Description: Intro Drama:Conventn  and Inovatn
# *****Course*****
# Type: 20512
# Format: ENG
# Rating: 242
# Description: S02
# Description: Intro Drama:Conventn  and Inovatn
# *****Course*****
# Type: 10508
# Format: ENG
# Rating: 301
# Description: F
# Description: Jun Sem: Epic and Novel
# *****Course*****
# Type: 20660
# Format: ANTH
# Rating: 434
# Description: S
# Description: Theories of Culture
# *****Course*****
# Type: 20513
# Format: ENG
# Rating: 302
# Description: S
# Description: Jun Sem:Irony, Allegory, Epic
# *****Course*****
# Type: 20647
# Format: ENG
# Rating: 303
# Description: S
# Description: Amer. Studies Seminar: TheEnd
# *****Course*****
# Type: 20514
# Format: ENG
# Rating: 333
# Description: S01
# Description: Fict:Wolff,Forster,Bloomsbury
# *****Course*****
# Type: 20515
# Format: ENG
# Rating: 333
# Description: S02
# Description: Fict: Novel  and  Theory Mimesis
# *****Course*****
# Type: 20516
# Format: ENG
# Rating: 338
# Description: S
# Description: Mod Fict:Representing Mothers
# *****Course*****
# Type: 10509
# Format: ENG
# Rating: 341
# Description: F01
# Description: American Lit: Race in America
# *****Course*****
# Type: 10510
# Format: ENG
# Rating: 341
# Description: F02
# Description: Amer Lit: The James Brothers
# *****Course*****
# Type: 20677
# Format: ENG
# Rating: 341
# Description: S
# Description: American Lit: Speaking ofRace
# *****Course*****
# Type: 10511
# Format: ENG
# Rating: 356
# Description: F
# Description: 20th Cent African-Amercan Lit
# *****Course*****
# Type: 10512
# Format: ENG
# Rating: 363
# Description: F
# Description: Love in Shakespeare
# *****Course*****
# Type: 10458
# Format: ART
# Rating: 161
# Description: F01
# Description: Introductory Drawing
# *****Course*****
# Type: 20517
# Format: ENG
# Rating: 363
# Description: S
# Description: Skepticism in Shakespeare
# *****Course*****
# Type: 10752
# Format: ENG
# Rating: 366
# Description: F
# Description: Poetry: Pound and H.D.
# *****Course*****
# Type: 20518
# Format: ENG
# Rating: 384
# Description: S
# Description: Poetry  and  History:Contemp Amer
# *****Course*****
# Type: 10514
# Format: ENG
# Rating: 393
# Description: F
# Description: Literary Theory:EthicsReading
# *****Course*****
# Type: 10136
# Format: FREN
# Rating: 110
# Description: Y01
# Description: First Year French
# *****Course*****
# Type: 10137
# Format: FREN
# Rating: 110
# Description: Y02
# Description: First Year French
# *****Course*****
# Type: 10138
# Format: FREN
# Rating: 110
# Description: Y03
# Description: First Year French
# *****Course*****
# Type: 10139
# Format: FREN
# Rating: 210
# Description: Y01
# Description: Second Year French
# *****Course*****
# Type: 10140
# Format: FREN
# Rating: 210
# Description: Y02
# Description: Second Year French
# *****Course*****
# Type: 10141
# Format: FREN
# Rating: 210
# Description: Y03
# Description: Second Year French
# *****Course*****
# Type: 10459
# Format: ART
# Rating: 161
# Description: F02
# Description: Introductory Drawing
# *****Course*****
# Type: 10142
# Format: FREN
# Rating: 320
# Description: Y
# Description: Stylistics and Composition
# *****Course*****
# Type: 10495
# Format: FREN
# Rating: 332
# Description: F
# Description: Lit  and  Society (16th Century)
# *****Course*****
# Type: 20493
# Format: FREN
# Rating: 334
# Description: S
# Description: Lit  and  Society (18th Century)
# *****Course*****
# Type: 20494
# Format: FREN
# Rating: 341
# Description: S
# Description: Early Modern French Narrative
# *****Course*****
# Type: 20495
# Format: FREN
# Rating: 351
# Description: S
# Description: 17th Cent French Drama
# *****Course*****
# Type: 20496
# Format: FREN
# Rating: 381
# Description: S
# Description: 20th C French Poetry  and Poetics
# *****Course*****
# Type: 10496
# Format: FREN
# Rating: 382
# Description: F
# Description: 20th Century French Theatre
# *****Course*****
# Type: 10497
# Format: FREN
# Rating: 451
# Description: F
# Description: Seminar:Uses of Literature
# *****Course*****
# Type: 10143
# Format: GER
# Rating: 110
# Description: Y01
# Description: Frst Yr German:A Foundation
# *****Course*****
# Type: 10397
# Format: GER
# Rating: 110
# Description: Y02
# Description: Frst Yr German:A Foundation
# *****Course*****
# Type: 20465
# Format: ART
# Rating: 162
# Description: S
# Description: Figure Drawing
# *****Course*****
# Type: 10145
# Format: GER
# Rating: 220
# Description: Y
# Description: Secnd Yr Ger:CultralPerspctvs
# *****Course*****
# Type: 10498
# Format: GER
# Rating: 311
# Description: F
# Description: Adv Conversation and Writing
# *****Course*****
# Type: 20499
# Format: GER
# Rating: 312
# Description: S
# Description: Advancd Conversation and Writing
# *****Course*****
# Type: 20497
# Format: GER
# Rating: 321
# Description: S
# Description: Modernism: Berlin
# *****Course*****
# Type: 20502
# Format: GER
# Rating: 335
# Description: S
# Description: Contemporary German Prose
# *****Course*****
# Type: 10501
# Format: GER
# Rating: 341
# Description: F
# Description: Modern German Theatre
# *****Course*****
# Type: 10499
# Format: GER
# Rating: 391
# Description: F
# Description: German Thought Postmodrn Era
# *****Course*****
# Type: 20500
# Format: GER
# Rating: 392
# Description: S
# Description: German Theory II: Body Media
# *****Course*****
# Type: 10146
# Format: GRK
# Rating: 110
# Description: Y
# Description: First Year Greek
# *****Course*****
# Type: 10147
# Format: GRK
# Rating: 210
# Description: Y
# Description: Second Year Greek
# *****Course*****
# Type: 20466
# Format: ART
# Rating: 164
# Description: S
# Description: Printmaking
# *****Course*****
# Type: 10487
# Format: GRK
# Rating: 311
# Description: F
# Description: Advanced Greek
# *****Course*****
# Type: 20485
# Format: GRK
# Rating: 312
# Description: S
# Description: Advanced Greek
# *****Course*****
# Type: 20628
# Format: HIST
# Rating: 220
# Description: S
# Description: Late Imperial China
# *****Course*****
# Type: 10643
# Format: HIST
# Rating: 221
# Description: F
# Description: Modern China
# *****Course*****
# Type: 10644
# Format: HIST
# Rating: 275
# Description: F
# Description: Cultr  and  Society 19 CentAmerca
# *****Course*****
# Type: 20629
# Format: HIST
# Rating: 276
# Description: S
# Description: Culture and Society 20 Cent Amer
# *****Course*****
# Type: 10784
# Format: HIST
# Rating: 281
# Description: F
# Description: Introduction to Judaism
# *****Course*****
# Type: 10645
# Format: HIST
# Rating: 308
# Description: F01
# Description: Spcl Tops: Vietnam War
# *****Course*****
# Type: 10646
# Format: HIST
# Rating: 308
# Description: F02
# Description: Spcl Tops: Vietnam War
# *****Course*****
# Type: 10647
# Format: HIST
# Rating: 322
# Description: F
# Description: Subaltern Stds Historiography
# *****Course*****
# Type: 10453
# Format: ART
# Rating: 201
# Description: F
# Description: Introduction to Art History
# *****Course*****
# Type: 20630
# Format: HIST
# Rating: 325
# Description: S
# Description: The Family in China and Japan
# *****Course*****
# Type: 10648
# Format: HIST
# Rating: 335
# Description: F
# Description: Devel of Britain 1700-1830
# *****Course*****
# Type: 20631
# Format: HIST
# Rating: 343
# Description: S01
# Description: The Third Reich
# *****Course*****
# Type: 20632
# Format: HIST
# Rating: 343
# Description: S02
# Description: The Third Reich
# *****Course*****
# Type: 20633
# Format: HIST
# Rating: 344
# Description: S01
# Description: The Russian Revolution
# *****Course*****
# Type: 20634
# Format: HIST
# Rating: 344
# Description: S02
# Description: The Russian Revolution
# *****Course*****
# Type: 10649
# Format: HIST
# Rating: 345
# Description: F
# Description: Weimar:State,Society  and Culture
# *****Course*****
# Type: 10653
# Format: HIST
# Rating: 352
# Description: F
# Description: Old Regime France 1600-1750
# *****Course*****
# Type: 20640
# Format: HIST
# Rating: 356
# Description: S
# Description: The French Enlightenment
# *****Course*****
# Type: 20641
# Format: HIST
# Rating: 364
# Description: S
# Description: Civil War and Reconstruction
# *****Course*****
# Type: 20461
# Format: ART
# Rating: 201
# Description: S01
# Description: Introduction to Art History
# *****Course*****
# Type: 20635
# Format: HIST
# Rating: 367
# Description: S01
# Description: Gender and History
# *****Course*****
# Type: 20636
# Format: HIST
# Rating: 367
# Description: S02
# Description: Gender and History
# *****Course*****
# Type: 10650
# Format: HIST
# Rating: 369
# Description: F
# Description: American Slavery
# *****Course*****
# Type: 20637
# Format: HIST
# Rating: 384
# Description: S01
# Description: Mexico: Indepdence toRevolutn
# *****Course*****
# Type: 20638
# Format: HIST
# Rating: 384
# Description: S02
# Description: Mexico: Indepdence toRevolutn
# *****Course*****
# Type: 10651
# Format: HIST
# Rating: 386
# Description: F
# Description: Mexico  and  the Spanish Conquest
# *****Course*****
# Type: 10800
# Format: HIST
# Rating: 386
# Description: F02
# Description: Mexico  and  the Spanish Conquest
# *****Course*****
# Type: 10490
# Format: HIST
# Rating: 393
# Description: F
# Description: Ancient History: Rome
# *****Course*****
# Type: 20489
# Format: HIST
# Rating: 394
# Description: S
# Description: Specl Topics in Roman History
# *****Course*****
# Type: 10652
# Format: HIST
# Rating: 411
# Description: F
# Description: Jun Sem: Depression Era U.S.
# *****Course*****
# Type: 10579
# Format: ANTH
# Rating: 211
# Description: F03
# Description: Introduction to Anthropology
# *****Course*****
# Type: 20462
# Format: ART
# Rating: 201
# Description: S02
# Description: Introduction to Art History
# *****Course*****
# Type: 20639
# Format: HIST
# Rating: 412
# Description: S
# Description: Sem: Comty, Auth, Cult15-1700
# *****Course*****
# Type: 10072
# Format: HUM
# Rating: 110
# Description: Y
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10148
# Format: HUM
# Rating: 110
# Description: Y01
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10149
# Format: HUM
# Rating: 110
# Description: Y02
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10150
# Format: HUM
# Rating: 110
# Description: Y03
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10151
# Format: HUM
# Rating: 110
# Description: Y04
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10152
# Format: HUM
# Rating: 110
# Description: Y05
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10153
# Format: HUM
# Rating: 110
# Description: Y06
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10154
# Format: HUM
# Rating: 110
# Description: Y07
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10155
# Format: HUM
# Rating: 110
# Description: Y08
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10460
# Format: ART
# Rating: 271
# Description: F
# Description: Introductory Painting
# *****Course*****
# Type: 10156
# Format: HUM
# Rating: 110
# Description: Y09
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10157
# Format: HUM
# Rating: 110
# Description: Y10
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10158
# Format: HUM
# Rating: 110
# Description: Y11
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10159
# Format: HUM
# Rating: 110
# Description: Y12
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10160
# Format: HUM
# Rating: 110
# Description: Y13
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10161
# Format: HUM
# Rating: 110
# Description: Y14
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10749
# Format: HUM
# Rating: 110
# Description: Y25
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10162
# Format: HUM
# Rating: 110
# Description: Y15
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10163
# Format: HUM
# Rating: 110
# Description: Y16
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10164
# Format: HUM
# Rating: 110
# Description: Y17
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 20467
# Format: ART
# Rating: 272
# Description: S
# Description: Introductory Painting II
# *****Course*****
# Type: 10165
# Format: HUM
# Rating: 110
# Description: Y18
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10775
# Format: HUM
# Rating: 110
# Description: Y26
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10166
# Format: HUM
# Rating: 110
# Description: Y19
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10168
# Format: HUM
# Rating: 110
# Description: Y21
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10169
# Format: HUM
# Rating: 110
# Description: Y22
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10318
# Format: HUM
# Rating: 110
# Description: Y23
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10323
# Format: HUM
# Rating: 110
# Description: Y24
# Description: West Humanities: Greece  and Rome
# *****Course*****
# Type: 10073
# Format: HUM
# Rating: 210
# Description: Y
# Description: Early Modern Europe
# *****Course*****
# Type: 10175
# Format: HUM
# Rating: 210
# Description: Y01
# Description: Early Modern Europe
# *****Course*****
# Type: 10176
# Format: HUM
# Rating: 210
# Description: Y02
# Description: Early Modern Europe
# *****Course*****
# Type: 10461
# Format: ART
# Rating: 281
# Description: F
# Description: Sculpture
# *****Course*****
# Type: 10177
# Format: HUM
# Rating: 210
# Description: Y03
# Description: Early Modern Europe
# *****Course*****
# Type: 10178
# Format: HUM
# Rating: 210
# Description: Y04
# Description: Early Modern Europe
# *****Course*****
# Type: 10074
# Format: HUM
# Rating: 220
# Description: Y
# Description: Modern Humanities
# *****Course*****
# Type: 10170
# Format: HUM
# Rating: 220
# Description: Y01
# Description: Modern Humanities
# *****Course*****
# Type: 10171
# Format: HUM
# Rating: 220
# Description: Y02
# Description: Modern Humanities
# *****Course*****
# Type: 10172
# Format: HUM
# Rating: 220
# Description: Y03
# Description: Modern Humanities
# *****Course*****
# Type: 10173
# Format: HUM
# Rating: 220
# Description: Y04
# Description: Modern Humanities
# *****Course*****
# Type: 10174
# Format: HUM
# Rating: 220
# Description: Y05
# Description: Modern Humanities
# *****Course*****
# Type: 10314
# Format: HUM
# Rating: 230
# Description: Y
# Description: Foundatns ChineseCivilization
# *****Course*****
# Type: 10315
# Format: HUM
# Rating: 230
# Description: Y01
# Description: Foundatns ChineseCivilization
# *****Course*****
# Type: 20468
# Format: ART
# Rating: 282
# Description: S
# Description: Sculpture II
# *****Course*****
# Type: 10316
# Format: HUM
# Rating: 230
# Description: Y02
# Description: Foundatns ChineseCivilization
# *****Course*****
# Type: 10317
# Format: HUM
# Rating: 230
# Description: Y03
# Description: Foundatns ChineseCivilization
# *****Course*****
# Type: 10179
# Format: LAT
# Rating: 110
# Description: Y
# Description: First Year Latin
# *****Course*****
# Type: 10180
# Format: LAT
# Rating: 210
# Description: Y
# Description: Second Year Latin
# *****Course*****
# Type: 10486
# Format: LAT
# Rating: 311
# Description: F
# Description: Advanced Latin
# *****Course*****
# Type: 20484
# Format: LAT
# Rating: 312
# Description: S
# Description: Advanced Latin
# *****Course*****
# Type: 10481
# Format: LING
# Rating: 311
# Description: F
# Description: General Linguistics
# *****Course*****
# Type: 10484
# Format: LING
# Rating: 313
# Description: F
# Description: Language and Society
# *****Course*****
# Type: 10483
# Format: LING
# Rating: 323
# Description: F
# Description: Introductory Syntax
# *****Course*****
# Type: 20481
# Format: LING
# Rating: 328
# Description: S
# Description: Morphosyntactic Typology
# *****Course*****
# Type: 10454
# Format: ART
# Rating: 315
# Description: F
# Description: Early Medieval Art
# *****Course*****
# Type: 20482
# Format: LING
# Rating: 348
# Description: S
# Description: Languages the Americas:Mayan
# *****Course*****
# Type: 10588
# Format: LING
# Rating: 392
# Description: F01
# Description: Structuralism and Semiotics
# *****Course*****
# Type: 10598
# Format: LING
# Rating: 392
# Description: F02
# Description: Structuralism and Semiotics
# *****Course*****
# Type: 10747
# Format: LING
# Rating: 393
# Description: F
# Description: Psycholinguistics
# *****Course*****
# Type: 10747
# Format: LING
# Rating: 393
# Description: F
# Description: Psycholinguistics
# *****Course*****
# Type: 20652
# Format: LING
# Rating: 396
# Description: S
# Description: Psych of Language Acquisition
# *****Course*****
# Type: 10538
# Format: LIT
# Rating: 266
# Description: F
# Description: Russian Short Fiction
# *****Course*****
# Type: 10757
# Format: LIT
# Rating: 320
# Description: F
# Description: 20-Cent Chin Fiction, 1919-49
# *****Course*****
# Type: 20498
# Format: LIT
# Rating: 321
# Description: S
# Description: Modernism: Berlin
# *****Course*****
# Type: 10756
# Format: LIT
# Rating: 326
# Description: F
# Description: Chinese Narrative Tradition
# *****Course*****
# Type: 20682
# Format: ART
# Rating: 316
# Description: S
# Description: Medieval Manuscript Illumin
# *****Course*****
# Type: 20657
# Format: LIT
# Rating: 334
# Description: S
# Description: Yijing: Text and Tradition
# *****Course*****
# Type: 10502
# Format: LIT
# Rating: 341
# Description: F
# Description: Modern German Theatre
# *****Course*****
# Type: 20665
# Format: LIT
# Rating: 343
# Description: S
# Description: 20-Century Chinese Poetry
# *****Course*****
# Type: 20487
# Format: LIT
# Rating: 363
# Description: S
# Description: Greek Tragedy
# *****Course*****
# Type: 20531
# Format: LIT
# Rating: 373
# Description: S
# Description: Russian Lit:Chekhov toPresent
# *****Course*****
# Type: 10540
# Format: LIT
# Rating: 379
# Description: F
# Description: The Myth of St. Petersburg
# *****Course*****
# Type: 10500
# Format: LIT
# Rating: 391
# Description: F
# Description: German Thought Postmod Era
# *****Course*****
# Type: 20501
# Format: LIT
# Rating: 392
# Description: S
# Description: German Theory II: Body Media
# *****Course*****
# Type: 20536
# Format: LIT
# Rating: 404
# Description: S
# Description: Russian Lit:Gogol  and Dostoevsky
# *****Course*****
# Type: 20533
# Format: LIT
# Rating: 408
# Description: S
# Description: Russ Decadent/SymbolistCultur
# *****Course*****
# Type: 10455
# Format: ART
# Rating: 333
# Description: F
# Description: Divine Comedy  and Visualizations
# *****Course*****
# Type: 10542
# Format: LIT
# Rating: 413
# Description: F
# Description: 20th C Russian CriticalTheory
# *****Course*****
# Type: 10430
# Format: MATH
# Rating: 111
# Description: F01
# Description: Calculus I
# *****Course*****
# Type: 10431
# Format: MATH
# Rating: 111
# Description: F02
# Description: Calculus I
# *****Course*****
# Type: 10432
# Format: MATH
# Rating: 111
# Description: F03
# Description: Calculus I
# *****Course*****
# Type: 10433
# Format: MATH
# Rating: 111
# Description: F04
# Description: Calculus I
# *****Course*****
# Type: 10434
# Format: MATH
# Rating: 111
# Description: F05
# Description: Calculus I
# *****Course*****
# Type: 10435
# Format: MATH
# Rating: 111
# Description: F06
# Description: Calculus I
# *****Course*****
# Type: 20442
# Format: MATH
# Rating: 111
# Description: S01
# Description: Calculus I
# *****Course*****
# Type: 20443
# Format: MATH
# Rating: 111
# Description: S02
# Description: Calculus I
# *****Course*****
# Type: 20444
# Format: MATH
# Rating: 112
# Description: S01
# Description: Calculus II
# *****Course*****
# Type: 20680
# Format: ART
# Rating: 343
# Description: S
# Description: Art and Politics in France
# *****Course*****
# Type: 20445
# Format: MATH
# Rating: 112
# Description: S02
# Description: Calculus II
# *****Course*****
# Type: 20446
# Format: MATH
# Rating: 112
# Description: S03
# Description: Calculus II
# *****Course*****
# Type: 20447
# Format: MATH
# Rating: 112
# Description: S04
# Description: Calculus II
# *****Course*****
# Type: 20448
# Format: MATH
# Rating: 112
# Description: S05
# Description: Calculus II
# *****Course*****
# Type: 20449
# Format: MATH
# Rating: 112
# Description: S06
# Description: Calculus II
# *****Course*****
# Type: 10436
# Format: MATH
# Rating: 121
# Description: F01
# Description: Introduction to Computing
# *****Course*****
# Type: 10436
# Format: MATH
# Rating: 121
# Description: F01
# Description: Introduction to Computing
# *****Course*****
# Type: 10437
# Format: MATH
# Rating: 121
# Description: F02
# Description: Introduction to Computing
# *****Course*****
# Type: 10437
# Format: MATH
# Rating: 121
# Description: F02
# Description: Introduction to Computing
# *****Course*****
# Type: 20450
# Format: MATH
# Rating: 132
# Description: S
# Description: Introduction to Combinatorics
# *****Course*****
# Type: 20681
# Format: ART
# Rating: 344
# Description: S
# Description: Pol Hist of Art Between Wars
# *****Course*****
# Type: 10438
# Format: MATH
# Rating: 141
# Description: F01
# Description: Intro to Probability  and Statist
# *****Course*****
# Type: 10439
# Format: MATH
# Rating: 141
# Description: F02
# Description: Intro to Probability  and Statist
# *****Course*****
# Type: 10440
# Format: MATH
# Rating: 141
# Description: FL1
# Description: Intro to Probability  and Statist
# *****Course*****
# Type: 10441
# Format: MATH
# Rating: 141
# Description: FL2
# Description: Intro to Probability  and Statist
# *****Course*****
# Type: 10442
# Format: MATH
# Rating: 141
# Description: FL3
# Description: Intro to Probability  and Statist
# *****Course*****
# Type: 10443
# Format: MATH
# Rating: 211
# Description: F01
# Description: Introduction to Analysis I
# *****Course*****
# Type: 10444
# Format: MATH
# Rating: 211
# Description: F02
# Description: Introduction to Analysis I
# *****Course*****
# Type: 10445
# Format: MATH
# Rating: 211
# Description: F03
# Description: Introduction to Analysis I
# *****Course*****
# Type: 20451
# Format: MATH
# Rating: 212
# Description: S01
# Description: Introduction to Analysis II
# *****Course*****
# Type: 20452
# Format: MATH
# Rating: 212
# Description: S02
# Description: Introduction to Analysis II
# *****Course*****
# Type: 10580
# Format: ANTH
# Rating: 211
# Description: F04
# Description: Introduction to Anthropology
# *****Course*****
# Type: 10777
# Format: ART
# Rating: 348
# Description: F
# Description: Art  and  Pol in Weimar Republic
# *****Course*****
# Type: 20453
# Format: MATH
# Rating: 311
# Description: S
# Description: Complex Analysis
# *****Course*****
# Type: 10446
# Format: MATH
# Rating: 321
# Description: F
# Description: Advanced Calculus
# *****Course*****
# Type: 10447
# Format: MATH
# Rating: 331
# Description: F01
# Description: Linear Algebra
# *****Course*****
# Type: 10448
# Format: MATH
# Rating: 331
# Description: F02
# Description: Linear Algebra
# *****Course*****
# Type: 20454
# Format: MATH
# Rating: 331
# Description: S
# Description: Linear Algebra
# *****Course*****
# Type: 20455
# Format: MATH
# Rating: 332
# Description: S
# Description: Abstract Algebra
# *****Course*****
# Type: 20456
# Format: MATH
# Rating: 341
# Description: S
# Description: Geometry
# *****Course*****
# Type: 10449
# Format: MATH
# Rating: 372
# Description: F
# Description: Combinatorics
# *****Course*****
# Type: 20457
# Format: MATH
# Rating: 382
# Description: S
# Description: Data Structure  and  Algorithm
# *****Course*****
# Type: 20643
# Format: MATH
# Rating: 385
# Description: S
# Description: Computer Graphics
# *****Course*****
# Type: 20679
# Format: ART
# Rating: 349
# Description: S
# Description: New West in Amer Photography
# *****Course*****
# Type: 10450
# Format: MATH
# Rating: 391
# Description: F
# Description: Probability
# *****Course*****
# Type: 20458
# Format: MATH
# Rating: 412
# Description: S
# Description: Topics in Advanced AnalysisII
# *****Course*****
# Type: 20459
# Format: MATH
# Rating: 421
# Description: S
# Description: Elemetary Number Theory
# *****Course*****
# Type: 10451
# Format: MATH
# Rating: 431
# Description: F
# Description: Algebraic Structures
# *****Course*****
# Type: 10452
# Format: MATH
# Rating: 441
# Description: F
# Description: Topics In Computer Theory
# *****Course*****
# Type: 10329
# Format: MUS
# Rating: 103
# Description: F
# Description: Chamber Orchestra
# *****Course*****
# Type: 20324
# Format: MUS
# Rating: 103
# Description: S
# Description: Chamber Orchestra
# *****Course*****
# Type: 10321
# Format: MUS
# Rating: 105
# Description: F
# Description: Chorus
# *****Course*****
# Type: 20316
# Format: MUS
# Rating: 105
# Description: S
# Description: Chorus
# *****Course*****
# Type: 10322
# Format: MUS
# Rating: 107
# Description: F
# Description: Collegium Musicum
# *****Course*****
# Type: 10462
# Format: ART
# Rating: 371
# Description: F
# Description: Intermed Paint,Draw,PrintmakI
# *****Course*****
# Type: 20317
# Format: MUS
# Rating: 107
# Description: S
# Description: Collegium Musicum
# *****Course*****
# Type: 10464
# Format: MUS
# Rating: 110
# Description: F
# Description: Intro to Music Listening
# *****Course*****
# Type: 10465
# Format: MUS
# Rating: 111
# Description: F
# Description: Music Theory I
# *****Course*****
# Type: 10466
# Format: MUS
# Rating: 111
# Description: FL1
# Description: Music Theory I
# *****Course*****
# Type: 10467
# Format: MUS
# Rating: 111
# Description: FL2
# Description: Music Theory I
# *****Course*****
# Type: 10468
# Format: MUS
# Rating: 111
# Description: FL3
# Description: Music Theory I
# *****Course*****
# Type: 10469
# Format: MUS
# Rating: 111
# Description: FL4
# Description: Music Theory I
# *****Course*****
# Type: 20471
# Format: MUS
# Rating: 112
# Description: S
# Description: Theory II:IntermediateHarmony
# *****Course*****
# Type: 20472
# Format: MUS
# Rating: 112
# Description: SL1
# Description: Theory II:IntermediateHarmony
# *****Course*****
# Type: 20473
# Format: MUS
# Rating: 112
# Description: SL2
# Description: Theory II:IntermediateHarmony
# *****Course*****
# Type: 20469
# Format: ART
# Rating: 372
# Description: S
# Description: IntermedPaint,Draw,PrintmakII
# *****Course*****
# Type: 20474
# Format: MUS
# Rating: 122
# Description: S
# Description: Survey of Western Music
# *****Course*****
# Type: 10470
# Format: MUS
# Rating: 212
# Description: F
# Description: Theory III: BaroqueCounterpnt
# *****Course*****
# Type: 20648
# Format: MUS
# Rating: 236
# Description: S
# Description: The String Quartet
# *****Course*****
# Type: 10471
# Format: MUS
# Rating: 251
# Description: F
# Description: Representation in Music
# *****Course*****
# Type: 20475
# Format: MUS
# Rating: 256
# Description: S
# Description: Romantic Music
# *****Course*****
# Type: 20476
# Format: MUS
# Rating: 262
# Description: S01
# Description: Jazz
# *****Course*****
# Type: 20477
# Format: MUS
# Rating: 262
# Description: S02
# Description: Jazz
# *****Course*****
# Type: 10472
# Format: MUS
# Rating: 264
# Description: F
# Description: Modernism in Music
# *****Course*****
# Type: 10473
# Format: MUS
# Rating: 311
# Description: F
# Description: Medieval and RenaissanceMusic
# *****Course*****
# Type: 20478
# Format: MUS
# Rating: 343
# Description: S
# Description: Advanced Analysis
# *****Course*****
# Type: 10463
# Format: ART
# Rating: 381
# Description: F
# Description: Intermed Sculp  and  Multimedia I
# *****Course*****
# Type: 10656
# Format: PE
# Rating: 101
# Description: AE6
# Description: Aerobics
# *****Course*****
# Type: 10657
# Format: PE
# Rating: 101
# Description: AE7
# Description: Aerobics
# *****Course*****
# Type: 10658
# Format: PE
# Rating: 101
# Description: AFD
# Description: African Dance
# *****Course*****
# Type: 10661
# Format: PE
# Rating: 101
# Description: AIK
# Description: Aikido
# *****Course*****
# Type: 10659
# Format: PE
# Rating: 101
# Description: AR3
# Description: Archery
# *****Course*****
# Type: 10660
# Format: PE
# Rating: 101
# Description: AR4
# Description: Archery
# *****Course*****
# Type: 10664
# Format: PE
# Rating: 101
# Description: BEL
# Description: Bellydance
# *****Course*****
# Type: 10662
# Format: PE
# Rating: 101
# Description: BRB
# Description: BallROOM Dance-Beginning
# *****Course*****
# Type: 10663
# Format: PE
# Rating: 101
# Description: BRI
# Description: BallROOM Dance-Intermediate
# *****Course*****
# Type: 10665
# Format: PE
# Rating: 101
# Description: CAN
# Description: Canoeing
# *****Course*****
# Type: 20470
# Format: ART
# Rating: 382
# Description: S
# Description: Intermed Sculp  and  MultimediaII
# *****Course*****
# Type: 10680
# Format: PE
# Rating: 101
# Description: DEF
# Description: Self Defense
# *****Course*****
# Type: 10666
# Format: PE
# Rating: 101
# Description: FEN
# Description: Fencing
# *****Course*****
# Type: 10667
# Format: PE
# Rating: 101
# Description: FLK
# Description: Folkdance
# *****Course*****
# Type: 10668
# Format: PE
# Rating: 101
# Description: GLF
# Description: Golf
# *****Course*****
# Type: 10698
# Format: PE
# Rating: 101
# Description: HAT
# Description: Yoga-Hatha
# *****Course*****
# Type: 10671
# Format: PE
# Rating: 101
# Description: JDO
# Description: Judo
# *****Course*****
# Type: 10670
# Format: PE
# Rating: 101
# Description: JGL
# Description: Juggling
# *****Course*****
# Type: 10669
# Format: PE
# Rating: 101
# Description: JIT
# Description: Jitterbug
# *****Course*****
# Type: 10697
# Format: PE
# Rating: 101
# Description: KUN
# Description: Yoga-Kundilini
# *****Course*****
# Type: 10672
# Format: PE
# Rating: 101
# Description: KYI
# Description: Kayaking-Intermediate
# *****Course*****
# Type: 20464
# Format: ART
# Rating: 425
# Description: S
# Description: Leonardo, Raphael,Michelangel
# *****Course*****
# Type: 10673
# Format: PE
# Rating: 101
# Description: LIF
# Description: Lifeguard Training
# *****Course*****
# Type: 10699
# Format: PE
# Rating: 101
# Description: REL
# Description: Yoga-Relaxaion
# *****Course*****
# Type: 10674
# Format: PE
# Rating: 101
# Description: ROC
# Description: Rock Climbing
# *****Course*****
# Type: 10675
# Format: PE
# Rating: 101
# Description: RUG
# Description: Rugby-Men and Women
# *****Course*****
# Type: 10750
# Format: PE
# Rating: 101
# Description: RWB
# Description: Rowing-Beginning
# *****Course*****
# Type: 10751
# Format: PE
# Rating: 101
# Description: RWI
# Description: Rowing-Intermediate
# *****Course*****
# Type: 10683
# Format: PE
# Rating: 101
# Description: SFT
# Description: Softball
# *****Course*****
# Type: 10684
# Format: PE
# Rating: 101
# Description: SQB
# Description: Squash-Beginning
# *****Course*****
# Type: 10685
# Format: PE
# Rating: 101
# Description: SQI
# Description: Squash-Intermediate
# *****Course*****
# Type: 10678
# Format: PE
# Rating: 101
# Description: SR2
# Description: Sailing
# *****Course*****
# Type: 10594
# Format: BIOL
# Rating: 101
# Description: F
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 10676
# Format: PE
# Rating: 101
# Description: ST2
# Description: Sailing
# *****Course*****
# Type: 10677
# Format: PE
# Rating: 101
# Description: SW2
# Description: Sailing
# *****Course*****
# Type: 10689
# Format: PE
# Rating: 101
# Description: TCB
# Description: Tai Chi-Beginning
# *****Course*****
# Type: 10690
# Format: PE
# Rating: 101
# Description: TCI
# Description: Tai Chi-Intermediate
# *****Course*****
# Type: 10693
# Format: PE
# Rating: 101
# Description: TNA
# Description: Tennis-Advanced
# *****Course*****
# Type: 10691
# Format: PE
# Rating: 101
# Description: TNB
# Description: Tennis-Beginning
# *****Course*****
# Type: 10692
# Format: PE
# Rating: 101
# Description: TNI
# Description: Tennis-Intermediate
# *****Course*****
# Type: 10694
# Format: PE
# Rating: 101
# Description: ULT
# Description: Ultimate Frisbee
# *****Course*****
# Type: 10696
# Format: PE
# Rating: 101
# Description: WWR
# Description: White Water Rafting
# *****Course*****
# Type: 10701
# Format: PE
# Rating: 102
# Description: AE6
# Description: Aerobics
# *****Course*****
# Type: 10596
# Format: BIOL
# Rating: 101
# Description: FT3
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 10703
# Format: PE
# Rating: 102
# Description: AE7
# Description: Aerobics
# *****Course*****
# Type: 10704
# Format: PE
# Rating: 102
# Description: AFD
# Description: African Dance
# *****Course*****
# Type: 10705
# Format: PE
# Rating: 102
# Description: AIK
# Description: Aikido
# *****Course*****
# Type: 10707
# Format: PE
# Rating: 102
# Description: BAD
# Description: Badminton
# *****Course*****
# Type: 10709
# Format: PE
# Rating: 102
# Description: BBC
# Description: Basketball-Coed
# *****Course*****
# Type: 10706
# Format: PE
# Rating: 102
# Description: BCN
# Description: Backcountry Navigation
# *****Course*****
# Type: 10708
# Format: PE
# Rating: 102
# Description: BD1
# Description: Badminton
# *****Course*****
# Type: 10713
# Format: PE
# Rating: 102
# Description: BEL
# Description: Bellydance
# *****Course*****
# Type: 10714
# Format: PE
# Rating: 102
# Description: BOW
# Description: Bowling
# *****Course*****
# Type: 10711
# Format: PE
# Rating: 102
# Description: BRB
# Description: BallROOM Dance-Beginning
# *****Course*****
# Type: 10599
# Format: BIOL
# Rating: 101
# Description: FT7
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 10712
# Format: PE
# Rating: 102
# Description: BRI
# Description: BallROOM Dance-Intermediate
# *****Course*****
# Type: 10727
# Format: PE
# Rating: 102
# Description: DEF
# Description: Self Defense
# *****Course*****
# Type: 10715
# Format: PE
# Rating: 102
# Description: FEN
# Description: Fencing
# *****Course*****
# Type: 10716
# Format: PE
# Rating: 102
# Description: FLK
# Description: Folkdancing
# *****Course*****
# Type: 10717
# Format: PE
# Rating: 102
# Description: HAP
# Description: Hiking Around Portland
# *****Course*****
# Type: 10740
# Format: PE
# Rating: 102
# Description: HAT
# Description: Yoga-Hatha
# *****Course*****
# Type: 10721
# Format: PE
# Rating: 102
# Description: JGL
# Description: Juggling
# *****Course*****
# Type: 10720
# Format: PE
# Rating: 102
# Description: JIT
# Description: Jitterbug
# *****Course*****
# Type: 10722
# Format: PE
# Rating: 102
# Description: JUD
# Description: Judo
# *****Course*****
# Type: 10739
# Format: PE
# Rating: 102
# Description: KUN
# Description: Yoga-Kundlini
# *****Course*****
# Type: 10581
# Format: ANTH
# Rating: 211
# Description: F05
# Description: Introduction to Anthropology
# *****Course*****
# Type: 10600
# Format: BIOL
# Rating: 101
# Description: FW3
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 10723
# Format: PE
# Rating: 102
# Description: LIF
# Description: Lifeguard Training
# *****Course*****
# Type: 10781
# Format: PE
# Rating: 102
# Description: MOD
# Description: Modern Dance
# *****Course*****
# Type: 10741
# Format: PE
# Rating: 102
# Description: REL
# Description: Yoga-Relaxation
# *****Course*****
# Type: 10725
# Format: PE
# Rating: 102
# Description: ROC
# Description: Rock Climbing
# *****Course*****
# Type: 10724
# Format: PE
# Rating: 102
# Description: RQB
# Description: Raquetball-Beginning
# *****Course*****
# Type: 10726
# Format: PE
# Rating: 102
# Description: RUG
# Description: Rugby-Men and Women
# *****Course*****
# Type: 10730
# Format: PE
# Rating: 102
# Description: SQB
# Description: Squash-beginning
# *****Course*****
# Type: 10731
# Format: PE
# Rating: 102
# ...
# Format: PSY
# Rating: 121
# Description: FL2
# Description: Intro to Psychology
# *****Course*****
# Type: 10406
# Format: PSY
# Rating: 121
# Description: FL3
# Description: Intro to Psychology
# *****Course*****
# Type: 10408
# Format: PSY
# Rating: 121
# Description: FL4
# Description: Intro to Psychology
# *****Course*****
# Type: 10763
# Format: ANTH
# Rating: 211
# Description: F06
# Description: Introduction to Anthropology
# *****Course*****
# Type: 20587
# Format: BIOL
# Rating: 102
# Description: SW7
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 20401
# Format: PSY
# Rating: 122
# Description: S
# Description: Intro to Psychology II
# *****Course*****
# Type: 20408
# Format: PSY
# Rating: 122
# Description: SL1
# Description: Intro to Psychology II
# *****Course*****
# Type: 20411
# Format: PSY
# Rating: 122
# Description: SL2
# Description: Intro to Psychology II
# *****Course*****
# Type: 20414
# Format: PSY
# Rating: 122
# Description: SL3
# Description: Intro to Psychology II
# *****Course*****
# Type: 20416
# Format: PSY
# Rating: 122
# Description: SL4
# Description: Intro to Psychology II
# *****Course*****
# Type: 10413
# Format: PSY
# Rating: 322
# Description: F
# Description: Social Psychology
# *****Course*****
# Type: 10753
# Format: PSY
# Rating: 324
# Description: F
# Description: Health Psychology
# *****Course*****
# Type: 20662
# Format: PSY
# Rating: 326
# Description: S
# Description: Social Development
# *****Course*****
# Type: 20663
# Format: PSY
# Rating: 327
# Description: S
# Description: Community Psychology
# *****Course*****
# Type: 10414
# Format: PSY
# Rating: 333
# Description: F
# Description: Psychobiology
# *****Course*****
# Type: 20588
# Format: BIOL
# Rating: 102
# Description: SR3
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 20426
# Format: PSY
# Rating: 333
# Description: S
# Description: Psychobiology
# *****Course*****
# Type: 20428
# Format: PSY
# Rating: 336
# Description: S
# Description: Neuropsychology
# *****Course*****
# Type: 20429
# Format: PSY
# Rating: 338
# Description: S
# Description: Psychopharmacology
# *****Course*****
# Type: 20430
# Format: PSY
# Rating: 338
# Description: SL1
# Description: Psychopharmacology
# *****Course*****
# Type: 20431
# Format: PSY
# Rating: 338
# Description: SL2
# Description: Psychopharmacology
# *****Course*****
# Type: 10416
# Format: PSY
# Rating: 344
# Description: F
# Description: Thinking
# *****Course*****
# Type: 20432
# Format: PSY
# Rating: 348
# Description: S
# Description: Research Design  and  DataAnalysi
# *****Course*****
# Type: 20433
# Format: PSY
# Rating: 348
# Description: SL1
# Description: Research Design  and  DataAnalysi
# *****Course*****
# Type: 20434
# Format: PSY
# Rating: 348
# Description: SL2
# Description: Research Design  and  DataAnalysi
# *****Course*****
# Type: 10754
# Format: PSY
# Rating: 351
# Description: F
# Description: Psychopathology
# *****Course*****
# Type: 20589
# Format: BIOL
# Rating: 102
# Description: SR7
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 10417
# Format: PSY
# Rating: 361
# Description: F
# Description: Human Development
# *****Course*****
# Type: 20435
# Format: PSY
# Rating: 366
# Description: S
# Description: Cognitive Processes
# *****Course*****
# Type: 20436
# Format: PSY
# Rating: 366
# Description: SL1
# Description: Cognitive Processes
# *****Course*****
# Type: 20437
# Format: PSY
# Rating: 366
# Description: SL2
# Description: Cognitive Processes
# *****Course*****
# Type: 20438
# Format: PSY
# Rating: 373
# Description: S
# Description: Learning
# *****Course*****
# Type: 20425
# Format: PSY
# Rating: 383
# Description: S
# Description: Music Perception
# *****Course*****
# Type: 10755
# Format: PSY
# Rating: 385
# Description: F
# Description: Cross-Cultural Psychology
# *****Course*****
# Type: 10418
# Format: PSY
# Rating: 393
# Description: F
# Description: Psycholinguistics
# *****Course*****
# Type: 20440
# Format: PSY
# Rating: 396
# Description: S
# Description: Psych of Language Acquisition
# *****Course*****
# Type: 10420
# Format: PSY
# Rating: 401
# Description: F
# Description: Junior Seminar
# *****Course*****
# Type: 20590
# Format: BIOL
# Rating: 102
# Description: SF3
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 20441
# Format: PSY
# Rating: 433
# Description: S
# Description: Psychobiology Research
# *****Course*****
# Type: 20664
# Format: PSY
# Rating: 442
# Description: S
# Description: Clinical Psychology
# *****Course*****
# Type: 10759
# Format: REL
# Rating: 152
# Description: F
# Description: Introduction to Judaism
# *****Course*****
# Type: 20521
# Format: REL
# Rating: 154
# Description: S
# Description: Intro to Religions of Asia
# *****Course*****
# Type: 10523
# Format: REL
# Rating: 155
# Description: F
# Description: Introduction to Islam
# *****Course*****
# Type: 10524
# Format: REL
# Rating: 201
# Description: F
# Description: Theory  and  Method in RelStudies
# *****Course*****
# Type: 10785
# Format: REL
# Rating: 201
# Description: F01
# Description: Theory  and Methods in RelStudies
# *****Course*****
# Type: 10786
# Format: REL
# Rating: 201
# Description: F02
# Description: Theory  and Methods in RelStudies
# *****Course*****
# Type: 10787
# Format: REL
# Rating: 201
# Description: F03
# Description: Theory  and Methods in RelStudies
# *****Course*****
# Type: 20522
# Format: REL
# Rating: 301
# Description: S
# Description: History of Religion
# *****Course*****
# Type: 20591
# Format: BIOL
# Rating: 102
# Description: SF7
# Description: Intro Biology Lect and Lab
# *****Course*****
# Type: 10525
# Format: REL
# Rating: 313
# Description: F
# Description: Chinese Mahayana Texts
# *****Course*****
# Type: 20523
# Format: REL
# Rating: 363
# Description: S
# Description: Missing Persons World ofIslam
# *****Course*****
# Type: 10760
# Format: REL
# Rating: 366
# Description: F
# Description: Romanticism and Religion
# *****Course*****
# Type: 10527
# Format: REL
# Rating: 384
# Description: F
# Description: Spcl Top Ancient Christianity
# *****Course*****
# Type: 20666
# Format: REL
# Rating: 399
# Description: S
# Description: Junior Seminar
# *****Course*****
# Type: 10197
# Format: RUSS
# Rating: 120
# Description: Y
# Description: First Year Russian
# *****Course*****
# Type: 10799
# Format: RUSS
# Rating: 120
# Description: Y02
# Description: First Year Russian
# *****Course*****
# Type: 10799
# Format: RUSS
# Rating: 120
# Description: Y02
# Description: First Year Russian
# *****Course*****
# Type: 10198
# Format: RUSS
# Rating: 220
# Description: Y
# Description: Second Year Russian
# *****Course*****
# Type: 10537
# Format: RUSS
# Rating: 266
# Description: F
# Description: Russian Short Fiction
# *****Course*****
# Type: 20593
# Format: BIOL
# Rating: 332
# Description: S
# Description: Vascular Plant Diversity
# *****Course*****
# Type: 10536
# Format: RUSS
# Rating: 300
# Description: F
# Description: Advanced Russian
# *****Course*****
# Type: 20534
# Format: RUSS
# Rating: 355
# Description: S
# Description: 20th Century Russian Poetry
# *****Course*****
# Type: 20530
# Format: RUSS
# Rating: 373
# Description: S
# Description: Mod Russ Lit:Chekov toPresent
# *****Course*****
# Type: 10539
# Format: RUSS
# Rating: 379
# Description: F
# Description: The Myth of St. Petersburg
# *****Course*****
# Type: 20535
# Format: RUSS
# Rating: 404
# Description: S
# Description: Russ Lit: Gogol  and  Dostoevsky
# *****Course*****
# Type: 20532
# Format: RUSS
# Rating: 408
# Description: S
# Description: Russ Decadent/SymbolistCultur
# *****Course*****
# Type: 10541
# Format: RUSS
# Rating: 413
# Description: F
# Description: 20th C Russian CriticalTheory
# *****Course*****
# Type: 10474
# Format: SOC
# Rating: 211
# Description: F
# Description: Introduction to Sociology
# *****Course*****
# Type: 10475
# Format: SOC
# Rating: 211
# Description: F01
# Description: Introduction to Sociology
# *****Course*****
# Type: 10476
# Format: SOC
# Rating: 211
# Description: F02
# Description: Introduction to Sociology
# *****Course*****
# Type: 20594
# Format: BIOL
# Rating: 332
# Description: SL1
# Description: Vascular Plant Diversity
# *****Course*****
# Type: 10477
# Format: SOC
# Rating: 211
# Description: F03
# Description: Introduction to Sociology
# *****Course*****
# Type: 10478
# Format: SOC
# Rating: 211
# Description: F04
# Description: Introduction to Sociology
# *****Course*****
# Type: 10479
# Format: SOC
# Rating: 211
# Description: F05
# Description: Introduction to Sociology
# *****Course*****
# Type: 10480
# Format: SOC
# Rating: 211
# Description: F06
# Description: Introduction to Sociology
# *****Course*****
# Type: 20684
# Format: SOC
# Rating: 244
# Description: S01
# Description: Race and Ethnicity
# *****Course*****
# Type: 20685
# Format: SOC
# Rating: 244
# Description: S02
# Description: Race and Ethnicity
# *****Course*****
# Type: 20653
# Format: SOC
# Rating: 283
# Description: S01
# Description: Sociology of Religion
# *****Course*****
# Type: 20654
# Format: SOC
# Rating: 283
# Description: S02
# Description: Sociology of Religion
# *****Course*****
# Type: 10520
# Format: SOC
# Rating: 311
# Description: F
# Description: Research Methods
# *****Course*****
# Type: 20646
# Format: SOC
# Rating: 321
# Description: S
# Description: American Capitalism
# *****Course*****
# Type: 20595
# Format: BIOL
# Rating: 332
# Description: SL2
# Description: Vascular Plant Diversity
# *****Course*****
# Type: 10522
# Format: SOC
# Rating: 363
# Description: F
# Description: Sociology of Culture
# *****Course*****
# Type: 10199
# Format: SPAN
# Rating: 110
# Description: Y01
# Description: First Year Spanish
# *****Course*****
# Type: 10200
# Format: SPAN
# Rating: 110
# Description: Y02
# Description: First Year Spanish
# *****Course*****
# Type: 10201
# Format: SPAN
# Rating: 110
# Description: Y03
# Description: First Year Spanish
# *****Course*****
# Type: 10202
# Format: SPAN
# Rating: 210
# Description: Y01
# Description: Second Year Spanish
# *****Course*****
# Type: 10203
# Format: SPAN
# Rating: 210
# Description: Y02
# Description: Second Year Spanish
# *****Course*****
# Type: 10378
# Format: SPAN
# Rating: 210
# Description: Y03
# Description: Second Year Spanish
# *****Course*****
# Type: 10491
# Format: SPAN
# Rating: 321
# Description: F01
# Description: Theory  and  Practice HispanicLit
# *****Course*****
# Type: 10492
# Format: SPAN
# Rating: 321
# Description: F02
# Description: Theory  and  Practice HispanicLit
# *****Course*****
# Type: 20492
# Format: SPAN
# Rating: 322
# Description: S
# Description: Spanish Short Story
# *****Course*****
# Type: 10610
# Format: BIOL
# Rating: 342
# Description: F
# Description: Animal Behav.  and  Behav.Ecology
# *****Course*****
# Type: 10494
# Format: SPAN
# Rating: 375
# Description: F
# Description: Modern Peninsular Drama
# *****Course*****
# Type: 20491
# Format: SPAN
# Rating: 395
# Description: S
# Description: Mod Spanish American Drama
# *****Course*****
# Type: 20683
# Format: SPAN
# Rating: 413
# Description: S
# Description: Penin Lit: Dogma  and  Disbelief
# *****Course*****
# Type: 10493
# Format: SPAN
# Rating: 442
# Description: F01
# Description: Spl Tops Span Amer Lit:Borges
# *****Course*****
# Type: 10770
# Format: SPAN
# Rating: 442
# Description: F02
# Description: The City in Span Amer Lit
# *****Course*****
# Type: 20490
# Format: SPAN
# Rating: 442
# Description: S
# Description: Lit Responses to Dictatorship
# *****Course*****
# Type: 10528
# Format: THEA
# Rating: 110
# Description: F
# Description: Introduction to Theatre
# *****Course*****
# Type: 10530
# Format: THEA
# Rating: 205
# Description: F01
# Description: Masks  and  Make-up Design
# *****Course*****
# Type: 10531
# Format: THEA
# Rating: 205
# Description: F02
# Description: Design for the Theatre: Sets
# *****Course*****
# Type: 20525
# Format: THEA
# Rating: 206
# Description: S01
# Description: Costume History  and  Design
# *****Course*****
# Type: 10611
# Format: BIOL
# Rating: 342
# Description: FL1
# Description: Animal Behav.  and  Behav.Ecology
# *****Course*****
# Type: 20526
# Format: THEA
# Rating: 206
# Description: S02
# Description: Design for Theatre: Lights
# *****Course*****
# Type: 10532
# Format: THEA
# Rating: 210
# Description: F
# Description: Acting Laboratory
# *****Course*****
# Type: 10533
# Format: THEA
# Rating: 250
# Description: F
# Description: Plays and Playhouses
# *****Course*****
# Type: 20527
# Format: THEA
# Rating: 270
# Description: S
# Description: Intercultr ExperimentsTheatre
# *****Course*****
# Type: 10534
# Format: THEA
# Rating: 275
# Description: F
# Description: Playwriting
# *****Course*****
# Type: 20528
# Format: THEA
# Rating: 310
# Description: S
# Description: Techniques of Acting
# *****Course*****
# Type: 10535
# Format: THEA
# Rating: 331
# Description: F
# Description: Directing I
# *****Course*****
# Type: 20529
# Format: THEA
# Rating: 334
# Description: S
# Description: Special Problems in Directing
# *****Course*****
# Type: 10744
# Format: HIST
# Rating: 556
# Description: F
# Description: Topics in FrenchEnlightenment
# *****Course*****
# Type: 10745
# Format: HUM
# Rating: 510
# Description: F
# Description: Greek Humanities
# *****Course*****
# Type: 10482
# Format: ANTH
# Rating: 311
# Description: F
# Description: General Linguistics
# *****Course*****
# Type: 10612
# Format: BIOL
# Rating: 342
# Description: FL2
# Description: Animal Behav.  and  Behav.Ecology
# *****Course*****
# Type: 20649
# Format: LBST
# Rating: 579
# Description: S
# Description: ColonizingAfrica:Conrad and Congo
# *****Course*****
# Type: 20650
# Format: LIT
# Rating: 560
# Description: S
# Description: Don Quixote  and  Narr. Theory
# *****Course*****
# Type: 10746
# Format: MATH
# Rating: 555
# Description: F
# Description: Ornamental Art
# *****Course*****
# Type: 20651
# Format: THEA
# Rating: 570
# Description: S
# Description: Experiments Intercult Theatre
# *****Course*****
# Type: 10613
# Format: BIOL
# Rating: 351
# Description: F
# Description: Developmental Biology
# *****Course*****
# Type: 10614
# Format: BIOL
# Rating: 351
# Description: FL1
# Description: Developmental Biology
# *****Course*****
# Type: 10615
# Format: BIOL
# Rating: 351
# Description: FL2
# Description: Developmental Biology
# *****Course*****
# Type: 20597
# Format: BIOL
# Rating: 356
# Description: S
# Description: Genetics and Gene Regulation
# *****Course*****
# Type: 20599
# Format: BIOL
# Rating: 356
# Description: SL1
# Description: Genetics and Gene Regulation
# *****Course*****
# Type: 20600
# Format: BIOL
# Rating: 356
# Description: SL2
# Description: Genetics and Gene Regulation
# *****Course*****
# Type: 10771
# Format: BIOL
# Rating: 358
# Description: F
# Description: Microbiology
# *****Course*****
# Type: 10772
# Format: BIOL
# Rating: 358
# Description: FL1
# Description: Microbiology
# *****Course*****
# Type: 10773
# Format: BIOL
# Rating: 358
# Description: FL2
# Description: Microbiology
# *****Course*****
# Type: 10485
# Format: ANTH
# Rating: 313
# Description: F
# Description: Language in Society
# *****Course*****
# Type: 20603
# Format: BIOL
# Rating: 358
# Description: S
# Description: Microbiology
# *****Course*****
# Type: 20604
# Format: BIOL
# Rating: 358
# Description: SL1
# Description: Microbiology
# *****Course*****
# Type: 20605
# Format: BIOL
# Rating: 358
# Description: SL2
# Description: Microbiology
# *****Course*****
# Type: 10616
# Format: BIOL
# Rating: 361
# Description: F
# Description: Genetics and MolecularBiology
# *****Course*****
# Type: 10617
# Format: BIOL
# Rating: 361
# Description: FL1
# Description: Genetics and MolecularBiology
# *****Course*****
# Type: 10618
# Format: BIOL
# Rating: 361
# Description: FL2
# Description: Genetics and MolecularBiology
# *****Course*****
# Type: 10619
# Format: BIOL
# Rating: 361
# Description: FL3
# Description: Genetics and MolecularBiology
# *****Course*****
# Type: 20606
# Format: BIOL
# Rating: 366
# Description: S
# Description: Population Bio:Ecolgy and Evolutn
# *****Course*****
# Type: 20608
# Format: BIOL
# Rating: 366
# Description: SL1
# Description: Population Bio:Ecolgy and Evolutn
# *****Course*****
# Type: 20610
# Format: BIOL
# Rating: 366
# Description: SL2
# Description: Population Bio:Ecolgy and Evolutn
# *****Course*****
# Type: 10768
# Format: ANTH
# Rating: 339
# Description: F
# Description: Ethnic  and  Nation France  and  NAfr
# *****Course*****
# Type: 10410
# Format: BIOL
# Rating: 367
# Description: F
# Description: Scientific Computation
# *****Course*****
# Type: 20617
# Format: BIOL
# Rating: 372
# Description: S
# Description: Cellular Biology
# *****Course*****
# Type: 20620
# Format: BIOL
# Rating: 372
# Description: SL1
# Description: Cellular Biology
# *****Course*****
# Type: 20621
# Format: BIOL
# Rating: 372
# Description: SL2
# Description: Cellular Biology
# *****Course*****
# Type: 10620
# Format: BIOL
# Rating: 381
# Description: F
# Description: Animal Physiology
# *****Course*****
# Type: 10622
# Format: BIOL
# Rating: 381
# Description: FL1
# Description: Animal Physiology
# *****Course*****
# Type: 10623
# Format: BIOL
# Rating: 381
# Description: FL2
# Description: Animal Physiology
# *****Course*****
# Type: 10776
# Format: BIOL
# Rating: 388
# Description: F
# Description: Evolutionary Biology
# *****Course*****
# Type: 10778
# Format: BIOL
# Rating: 388
# Description: FL1
# Description: Evolutionary Biology
# *****Course*****
# Type: 10779
# Format: BIOL
# Rating: 388
# Description: FL2
# Description: Evolutionary Biology

# %% [raw]
# - Reference : Akuli
