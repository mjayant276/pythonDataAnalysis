# %% [markdown]
# <img src='./images/Pandas_logo.svg.png'>

# %% [markdown]
# ``Pandas`` is an open source Python library for data analysis. It gives Python the
# ability to work with spreadsheet-like data for fast data loading, manipulating,
# aligning, merging, etc. To give Python these enhanced features, Pandas
# introduces two new data types to Python: ``Series`` and ``DataFrame``. The
# DataFrame will represent your entire spreadsheet or rectangular data, whereas
# the Series is a single column of the DataFrame. A Pandas DataFrame can also
# be thought of as a dictionary or collection of Series.
#
# While NumPy and its ndarray object, which provides efficient storage and manipulation
# of dense typed arrays in Python. Pandas is a package built on top of NumPy, and provides an
# efficient implementation of a DataFrame. DataFrames are essentially multidimensional
# arrays with attached row and column labels, and often with heterogeneous
# types and/or missing data. As well as offering a convenient storage interface for
# labeled data, Pandas implements a number of powerful data operations familiar to
# users of both database frameworks and spreadsheet programs.
#
# NumPy’s ndarray data structure provides essential features for the type of
# clean, well-organized data typically seen in numerical computing tasks. While it
# serves this purpose very well, its limitations become clear when we need more flexibility
# (attaching labels to data, working with missing data, etc.) and when attempting
# operations that do not map well to element-wise broadcasting (groupings, pivots,
# etc.), each of which is an important piece of analyzing the less structured data available
# in many forms in the world around us. Pandas, and in particular its Series and
# DataFrame objects, builds on the NumPy array structure and provides efficient access
# to these sorts of “data munging” tasks that occupy much of a data scientist’s time.

# %% [markdown]
# #### Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
# We shall learn about pandas datastructures and other aspects

# %% [markdown]
# #### Import Pandas as pd

# %%
## Let us start using the pandas libraray
## To use the library we shall import pandas as follows
## Pandas is the library name and in this jupyter notebook the alias name will be pd
import pandas as pd
import matplotlib.pyplot as plt

# %%
## to know the version of pandas we shall use the following version
## Pandas version is 1.5.3
pd.__version__
# Out:
# '1.5.3'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Jayanth\\Python_DataAnalysis\\Pandas'

# %% [markdown]
# ##### Read the csv file in Pandas as dataframe

# %%
df = pd.read_csv('C:\\Users\\Jayanth\\Python_DataAnalysis\\Pandas\\datasets\\us_homesales.csv')

# %% [markdown]
# #### Using head function on the dataframe display the dataframe

# %%
df.head(5)
# Out:
#    per_idx    per_name  cat_idx cat_code                       cat_desc  \
# 0        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 1        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 2        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 3        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 4        1  1963-01-01        1     SOLD  New Single-family Houses Sold
#
#    cat_indent  dt_idx dt_code                             dt_desc dt_unit  \
# 0           0       5  MEDIAN                  Median Sales Price     DOL
# 1           0       2  NOTSTD         Houses that are Not Started       K
# 2           0       3  UNDERC  Houses that are Under Construction       K
# 3           0       4  COMPED           Houses that are Completed       K
# 4           0       1   TOTAL                          All Houses       K
#
#    et_idx et_code et_desc et_unit  geo_idx geo_code       geo_desc  is_adj  \
# 0       0     NaN     NaN     NaN        1       US  United States       0
# 1       0     NaN     NaN     NaN        1       US  United States       0
# 2       0     NaN     NaN     NaN        1       US  United States       0
# 3       0     NaN     NaN     NaN        1       US  United States       0
# 4       0     NaN     NaN     NaN        1       US  United States       0
#
#        val  serialid
# 0  17200.0         1
# 1      9.0         2
# 2     11.0         3
# 3     22.0         4
# 4     42.0         5

# %% [markdown]
# #### Get the datatypes of the dataframe

# %%
df.dtypes
# Out:
# per_idx         int64
# per_name       object
# cat_idx         int64
# cat_code       object
# cat_desc       object
# cat_indent      int64
# dt_idx          int64
# dt_code        object
# dt_desc        object
# dt_unit        object
# et_idx          int64
# et_code        object
# et_desc        object
# et_unit        object
# geo_idx         int64
# geo_code       object
# geo_desc       object
# is_adj          int64
# val           float64
# serialid        int64
# dtype: object

# %% [markdown]
# #### Total number of columns in the dataframe

# %%
len(df.columns)
# Out:
# 20

# %% [markdown]
# #### Know how many unique values are there in cat_code column - unique function on the column

# %%
df['cat_code'].unique()
# Out:
# array(['SOLD', 'ASOLD', 'FORSALE'], dtype=object)

# %% [markdown]
# #### Perform basic summary statistics on the dataframe

# %%
df.describe()
# Out:
#             per_idx       cat_idx  cat_indent        dt_idx        et_idx  \
# count  20404.000000  20404.000000     20404.0  20404.000000  20404.000000
# mean     405.189277      2.045677         0.0      1.898941      0.584101
# std      170.217740      0.902040         0.0      2.202395      1.450598
# min        1.000000      1.000000         0.0      0.000000      0.000000
# 25%      267.000000      1.000000         0.0      1.000000      0.000000
# 50%      450.000000      2.000000         0.0      1.000000      0.000000
# 75%      548.000000      3.000000         0.0      3.000000      0.000000
# max      646.000000      3.000000         0.0      8.000000      8.000000
#
#             geo_idx        is_adj            val      serialid
# count  20404.000000  20404.000000   18610.000000  20404.000000
# mean       2.070378      0.247599    9352.033638  10202.500000
# std        1.437194      0.431628   42851.074035   5890.271782
# min        1.000000      0.000000       1.000000      1.000000
# 25%        1.000000      0.000000      11.000000   5101.750000
# 50%        1.000000      0.000000      31.500000  10202.500000
# 75%        3.000000      0.000000     151.750000  15303.250000
# max        5.000000      1.000000  384000.000000  20404.000000

# %%
df.groupby(by=['cat_code'],dropna=True).count()
# Out:
#           per_idx  per_name  cat_idx  cat_desc  cat_indent  dt_idx  dt_code  \
# cat_code
# ASOLD        3760      3760     3760      3760        3760    3760     2750
# FORSALE      8788      8788     8788      8788        8788    8788     6768
# SOLD         7856      7856     7856      7856        7856    7856     5836
#
#           dt_desc  dt_unit  et_idx  et_code  et_desc  et_unit  geo_idx  \
# cat_code
# ASOLD        2750     2750    3760     1010     1010     1010     3760
# FORSALE      6768     6768    8788     2020     2020     2020     8788
# SOLD         5836     5836    7856     2020     2020     2020     7856
#
#           geo_code  geo_desc  is_adj   val  serialid
# cat_code
# ASOLD         3760      3760    3760  3760      3760
# FORSALE       8788      8788    8788  6994      8788
# SOLD          7856      7856    7856  7856      7856

# %% [markdown]
# #### Convert object type data into date format

# %%
df['date'] =  pd.to_datetime(df['per_name'], format='%Y-%m-%d')

# %%
df.head(5)
# Out:
#    per_idx    per_name  cat_idx cat_code                       cat_desc  \
# 0        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 1        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 2        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 3        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 4        1  1963-01-01        1     SOLD  New Single-family Houses Sold
#
#    cat_indent  dt_idx dt_code                             dt_desc dt_unit  \
# 0           0       5  MEDIAN                  Median Sales Price     DOL
# 1           0       2  NOTSTD         Houses that are Not Started       K
# 2           0       3  UNDERC  Houses that are Under Construction       K
# 3           0       4  COMPED           Houses that are Completed       K
# 4           0       1   TOTAL                          All Houses       K
#
#    ...  et_code et_desc et_unit geo_idx  geo_code       geo_desc is_adj  \
# 0  ...      NaN     NaN     NaN       1        US  United States      0
# 1  ...      NaN     NaN     NaN       1        US  United States      0
# 2  ...      NaN     NaN     NaN       1        US  United States      0
# 3  ...      NaN     NaN     NaN       1        US  United States      0
# 4  ...      NaN     NaN     NaN       1        US  United States      0
#
#        val  serialid       date
# 0  17200.0         1 1963-01-01
# 1      9.0         2 1963-01-01
# 2     11.0         3 1963-01-01
# 3     22.0         4 1963-01-01
# 4     42.0         5 1963-01-01
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Splitting the data column into day, month and year

# %%
df['year']= df['date'].dt.year
df['month']= df['date'].dt.month
df['day']= df['date'].dt.day
df.head(5)
# Out:
#    per_idx    per_name  cat_idx cat_code                       cat_desc  \
# 0        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 1        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 2        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 3        1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 4        1  1963-01-01        1     SOLD  New Single-family Houses Sold
#
#    cat_indent  dt_idx dt_code                             dt_desc dt_unit  \
# 0           0       5  MEDIAN                  Median Sales Price     DOL
# 1           0       2  NOTSTD         Houses that are Not Started       K
# 2           0       3  UNDERC  Houses that are Under Construction       K
# 3           0       4  COMPED           Houses that are Completed       K
# 4           0       1   TOTAL                          All Houses       K
#
#    ...  geo_idx geo_code       geo_desc is_adj      val serialid       date  \
# 0  ...        1       US  United States      0  17200.0        1 1963-01-01
# 1  ...        1       US  United States      0      9.0        2 1963-01-01
# 2  ...        1       US  United States      0     11.0        3 1963-01-01
# 3  ...        1       US  United States      0     22.0        4 1963-01-01
# 4  ...        1       US  United States      0     42.0        5 1963-01-01
#
#    year  month  day
# 0  1963      1    1
# 1  1963      1    1
# 2  1963      1    1
# 3  1963      1    1
# 4  1963      1    1
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Find the number of rows and columns in the dataframe

# %%
df.shape
# Out:
# (20404, 24)

# %% [markdown]
# #### How many sales values are there for each year

# %%
df.groupby('year').count()['per_idx']
# Out:
# year
# 1963    120
# 1964    120
# 1965    120
# 1966    120
# 1967    120
# 1968    120
# 1969    120
# 1970    120
# 1971    120
# 1972    120
# 1973    300
# 1974    300
# 1975    324
# 1976    324
# 1977    324
# 1978    324
# 1979    324
# 1980    324
# 1981    324
# 1982    324
# 1983    324
# 1984    324
# 1985    324
# 1986    324
# 1987    324
# 1988    324
# 1989    324
# 1990    324
# 1991    324
# 1992    324
# 1993    324
# 1994    324
# 1995    324
# 1996    324
# 1997    324
# 1998    324
# 1999    324
# 2000    624
# 2001    624
# 2002    624
# 2003    624
# 2004    624
# 2005    624
# 2006    624
# 2007    624
# 2008    624
# 2009    624
# 2010    624
# 2011    624
# 2012    624
# 2013    624
# 2014    624
# 2015    624
# 2016    520
# Name: per_idx, dtype: int64

# %% [markdown]
# #### Plot the dataframe using plot and matplotlib function

# %%
df.groupby('year').count()['per_idx'].plot()
plt.show()
